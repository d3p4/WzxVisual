# %%
#实践训练

# %%
#实践1
#导入相关库
import plotly.offline as py
import plotly.graph_objects as go

month = ['十二月','十一月','十月','九月','八月','七月','六月','五月','四月','三月','二月','一月'] 
price = [12,24,16,14,28,18,16,12,30,12,8,10]

fig = go.Figure(data=[go.Pie(labels=month, values=price, textinfo='label+percent',insidetextorientation='radial')])

#美化图形元素
fig.update_layout(
    xaxis_title="月份",      #X轴标题文本
    yaxis_title="销售额",    #Y轴标题文本
    legend_title="月份",    #图例标题文本
    width=700,height=500,   #设置图像的大小
    title = dict(
       text = "2019年价格因素导致的商品退单",
       x = 0.5,
       xanchor = 'center',
       xref = 'paper' 
    ),
    font=dict(
        family="Courier New, monospace",  #标题文字的字体
        size=20,                          #标题文字的大小
        color="RebeccaPurple"             #标题的颜色
    ),
    xaxis_title_font_family='Times New Roman', #额外设置x轴标题的字体
    yaxis_title_font_color = 'red'             #额外将y轴的字体设置为红色
)

#输出图形结果
py.plot(fig, filename='饼图.html')
# Out:
# '饼图.html'

# %%
#实践2
#导入相关库
import pygal
import pandas as pd

my_config = pygal.Config()
my_config.show_legend = True
 
#设置字体大小
my_config.style.title_font_size = 26
my_config.style.label_font_size = 16

#读取数据
df = pd.read_csv('D:/Python商业数据可视化实战/ch08/churn.csv', ',')

#设置雷达图的填充及数据范围
radar_chart = pygal.Radar(my_config,fill = False,range=(0,50))

#添加雷达图标题
radar_chart.title = '2019年各月份客户退单主要原因分析'

#添加雷达图顶点
radar_chart.x_labels = ['十二月','十一月','十月','九月','八月','七月','六月','五月','四月','三月','二月','一月'] 

#绘制雷达图区域
radar_chart.add('质量差', df['quality'])
radar_chart.add('服务差', df['service'])
radar_chart.add('价格高', df['price'])

#保存图像
radar_chart.render_to_file('雷达图.svg')

# %%
#实践3
#声明Notebook类型，必须在引入pyecharts.charts等模块前声明
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

from pyecharts import options as opts
from pyecharts.charts import Boxplot

v1 = [[19,28,26,27,28,28,22,29,12,24,14,16]]
v2 = [[34,32,25,32,40,41,46,35,35,45,41,38]]
v3 = [[12,24,16,14,28,18,16,12,30,12,8,10]]

#绘制箱形图
def boxpolt_base() -> Boxplot:  
    c = Boxplot()                  
    c.add_xaxis(["退单原因"])
    c.add_yaxis("质量差", c.prepare_data(v1))
    c.add_yaxis("服务差", c.prepare_data(v2))
    c.add_yaxis("价格高", c.prepare_data(v3))    
    c.set_global_opts(title_opts=opts.TitleOpts(title="2019年客户退单原因分析",title_textstyle_opts=opts.TextStyleOpts(font_size=20)),
       xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size = 16)),
       yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size = 16)),
       toolbox_opts=opts.ToolboxOpts(),
       legend_opts=opts.LegendOpts(is_show=True,item_width=40,item_height=20,textstyle_opts=opts.TextStyleOpts(font_size=16))
       )
    c.set_series_opts(label_opts=opts.LabelOpts(font_size = 16))
    return c

#第一次渲染时候调用load_javascript文件
boxpolt_base().load_javascript()
#展示数据可视化图表
boxpolt_base().render_notebook()
# Out:
# f:\uninstall\python39\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning:
#
# pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#
# f:\uninstall\python39\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning:
#
# pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="e765a9e3981d4e68a90bbec46d615ee7" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_e765a9e3981d4e68a90bbec46d615ee7 = echarts.init(
#             document.getElementById('e765a9e3981d4e68a90bbec46d615ee7'), 'white', {renderer: 'canvas'});
#         var option_e765a9e3981d4e68a90bbec46d615ee7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
# ...
